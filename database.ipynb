# %%
import pandas as pd

# %%
database = pd.read_excel(r'C:\Users\server\Documents\git\lib\MoNA-export-All_Spectra.xlsx',index_col = 'Unnamed: 0')

# %%
database
# Out:
#                            Inchikey   Precursor  \
# 0       QKLPUVXBJHRFQZ-UHFFFAOYSA-N  284.013474
# 1       XOXHILFPRYWFOD-UHFFFAOYSA-N  284.013474
# 2       ASWVTGNCAZCNNR-UHFFFAOYSA-N  278.083747
# 3       ASWVTGNCAZCNNR-UHFFFAOYSA-N  278.083747
# 4       ASWVTGNCAZCNNR-UHFFFAOYSA-N  278.083747
# ...                             ...         ...
# 693709  FGZVHXCJVPTHKF-UHFFFAOYSA-N  232.149471
# 693710  KHKJMJPOXGEQGW-UHFFFAOYSA-N  231.144326
# 693711                          NaN         NaN
# 693712                          NaN         NaN
# 693713  HBCJNYMMAKSEEM-UHFFFAOYSA-N  218.138685
#
#                                                      Frag       Formula  \
# 0       {53.0389:0.594951,54.0333:0.566811,55.0178:0.5...  C10H9ClN4O2S
# 1       {53.0389:0.594951,54.0333:0.566811,55.0178:0.5...  C10H9ClN4O2S
# 2       {53.0379:0.894101,54.0335:0.661867,55.0176:0.5...   C12H14N4O2S
# 3       {122.0703:0.766124,124.0861:36.693459,125.0892...   C12H14N4O2S
# ...

# %%
eval(database.loc[1,['Frag']].values[0])
# Out:
# {53.0389: 0.594951,
#  54.0333: 0.566811,
#  55.0178: 0.522592,
#  60.0552: 0.542692,
#  65.0382: 3.822962,
#  66.0423: 0.506512,
#  68.049: 7.963499,
#  78.0333: 0.727609,
#  79.0177: 1.057244,
#  92.0498: 7.702203,
#  93.0532: 0.731629,
#  96.0443: 0.623091,
#  108.0457: 12.172375,
#  109.0483: 1.181862,
#  110.0609: 4.904325,
#  120.0562: 3.095353,
#  130.0172: 5.656054,
#  132.0138: 1.515517,
#  156.0118: 100.0,
#  157.015: 8.884065,
#  158.008: 3.891301,
#  174.0228: 0.751729,
#  184.0757: 0.619071,
#  191.9647: 0.590931,
#  219.0438: 0.723589,
#  285.0221: 3.694324,
#  287.0184: 0.840167}
